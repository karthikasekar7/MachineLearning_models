# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
travel = pd.read_csv("Traveldata_train.csv");
survey = pd.read_csv("Surveydata_train.csv");

# %%
travel.head()
# Out:
#         ID  Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  2100001  Female  Loyal Customer  52.0              NaN     Business
# 1  2100002    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  2100003  Female  Loyal Customer  43.0  Business travel     Business
# 3  2100004  Female  Loyal Customer  44.0  Business travel     Business
# 4  2100005  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0

# %%
survey.head()
# Out:
#         ID  Overall_Experience      Seat_comfort Seat_Class  \
# 0  2100001                   0  need improvement  Green Car
# 1  2100002                   0              poor   Ordinary
# 2  2100003                   1  need improvement  Green Car
# 3  2100004                   0        acceptable   Ordinary
# 4  2100005                   1        acceptable   Ordinary
#
#   Arrival_time_convenient          Catering Platform_location  \
# 0               excellent         excellent   very convinient
# 1               excellent              poor  need improvement
# 2        need improvement  need improvement  need improvement
# 3        need improvement               NaN  need improvement
# 4              acceptable        acceptable        manageable
#
#   Onboardwifi_service Onboard_entertainment Online_support Onlinebooking_Ease  \
# 0                good      need improvement     acceptable   need improvement
# ...

# %%
travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      94379 non-null  int64
#  1   Gender                  94302 non-null  object
#  2   CustomerType            85428 non-null  object
#  3   Age                     94346 non-null  float64
#  4   TypeTravel              85153 non-null  object
#  5   Travel_Class            94379 non-null  object
#  6   Travel_Distance         94379 non-null  int64
#  7   DepartureDelay_in_Mins  94322 non-null  float64
#  8   ArrivalDelay_in_Mins    94022 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 6.5+ MB

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       94379 non-null  int64
#  1   Overall_Experience       94379 non-null  int64
#  2   Seat_comfort             94318 non-null  object
#  3   Seat_Class               94379 non-null  object
#  4   Arrival_time_convenient  85449 non-null  object
#  5   Catering                 85638 non-null  object
#  6   Platform_location        94349 non-null  object
#  7   Onboardwifi_service      94349 non-null  object
#  8   Onboard_entertainment    94361 non-null  object
#  9   Online_support           94288 non-null  object
#  10  Onlinebooking_Ease       94306 non-null  object
#  11  Onboard_service          86778 non-null  object
#  12  Leg_room                 94289 non-null  object
#  13  Baggage_handling         94237 non-null  object
# ...

# %%
travel.isnull().sum()
# Out:
# ID                           0
# Gender                      77
# CustomerType              8951
# Age                         33
# TypeTravel                9226
# Travel_Class                 0
# Travel_Distance              0
# DepartureDelay_in_Mins      57
# ArrivalDelay_in_Mins       357
# dtype: int64

# %%
travel.describe()
# Out:
#                  ID           Age  Travel_Distance  DepartureDelay_in_Mins  \
# count  9.437900e+04  94346.000000     94379.000000            94322.000000
# mean   2.147190e+06     39.419647      1978.888185               14.647092
# std    2.724501e+04     15.116632      1027.961019               38.138781
# min    2.100001e+06      7.000000        50.000000                0.000000
# 25%    2.123596e+06     27.000000      1359.000000                0.000000
# 50%    2.147190e+06     40.000000      1923.000000                0.000000
# 75%    2.170784e+06     51.000000      2538.000000               12.000000
# max    2.194379e+06     85.000000      6951.000000             1592.000000
#
#        ArrivalDelay_in_Mins
# count          94022.000000
# mean              15.005222
# std               38.439409
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%               13.000000
# max             1584.000000

# %%
survey.isnull().sum()
# Out:
# ID                            0
# Overall_Experience            0
# Seat_comfort                 61
# Seat_Class                    0
# Arrival_time_convenient    8930
# Catering                   8741
# Platform_location            30
# Onboardwifi_service          30
# Onboard_entertainment        18
# Online_support               91
# Onlinebooking_Ease           73
# Onboard_service            7601
# Leg_room                     90
# Baggage_handling            142
# Checkin_service              77
# Cleanliness                   6
# Online_boarding               6
# dtype: int64

# %%
shinkansen = pd.merge(travel,survey,on='ID')

# %%
shinkansen.head()
# Out:
#         ID  Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  2100001  Female  Loyal Customer  52.0              NaN     Business
# 1  2100002    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  2100003  Female  Loyal Customer  43.0  Business travel     Business
# 3  2100004  Female  Loyal Customer  44.0  Business travel     Business
# 4  2100005  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience  ... Onboardwifi_service Onboard_entertainment  \
# 0                   0  ...                good      need improvement
# ...

# %%
shinkansen['Gender'].unique()
# Out:
# array(['Female', 'Male', nan], dtype=object)

# %%
shinkansen.dropna(inplace=True)

# %%
shinkansen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55503 entries, 1 to 94375
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       55503 non-null  int64
#  1   Gender                   55503 non-null  object
#  2   CustomerType             55503 non-null  object
#  3   Age                      55503 non-null  float64
#  4   TypeTravel               55503 non-null  object
#  5   Travel_Class             55503 non-null  object
#  6   Travel_Distance          55503 non-null  int64
#  7   DepartureDelay_in_Mins   55503 non-null  float64
#  8   ArrivalDelay_in_Mins     55503 non-null  float64
#  9   Overall_Experience       55503 non-null  int64
#  10  Seat_comfort             55503 non-null  object
#  11  Seat_Class               55503 non-null  object
#  12  Arrival_time_convenient  55503 non-null  object
#  13  Catering                 55503 non-null  object
# ...

# %%
print("Gender:"+shinkansen['Gender'].unique())
print("CustomerType:"+shinkansen['CustomerType'].unique())
print("TypeTravel:"+shinkansen['TypeTravel'].unique())
print("Travel_Class:"+shinkansen['Travel_Class'].unique())
print("Seat_comfort:"+shinkansen['Seat_comfort'].unique())
print("Seat_Class:"+shinkansen['Seat_Class'].unique())
print("Arrival_time_convenient:"+shinkansen['Arrival_time_convenient'].unique())
print("Catering:"+shinkansen['Catering'].unique())
print("Platform_location:"+shinkansen['Platform_location'].unique())
print("Onboardwifi_service:"+shinkansen['Onboardwifi_service'].unique())
print("Onboard_entertainment:"+shinkansen['Onboard_entertainment'].unique())
print("Online_support:"+shinkansen['Online_support'].unique())
print("Onlinebooking_Ease:"+shinkansen['Onlinebooking_Ease'].unique())
print("Leg_room:"+shinkansen['Leg_room'].unique())
print("Baggage_handling:"+shinkansen['Baggage_handling'].unique())
print("Checkin_service:"+shinkansen['Checkin_service'].unique())
print("Cleanliness:"+shinkansen['Cleanliness'].unique())
print("Online_boarding:"+shinkansen['Online_boarding'].unique())
# Out:
# ['Gender:Male' 'Gender:Female']
# ['CustomerType:Loyal Customer' 'CustomerType:disloyal Customer']
# ['TypeTravel:Personal Travel' 'TypeTravel:Business travel']
# ['Travel_Class:Eco' 'Travel_Class:Business']
# ['Seat_comfort:poor' 'Seat_comfort:need improvement'
#  'Seat_comfort:acceptable' 'Seat_comfort:good' 'Seat_comfort:excellent'
#  'Seat_comfort:extremely poor']
# ['Seat_Class:Ordinary' 'Seat_Class:Green Car']
# ['Arrival_time_convenient:excellent'
#  'Arrival_time_convenient:need improvement'
#  'Arrival_time_convenient:acceptable' 'Arrival_time_convenient:good'
#  'Arrival_time_convenient:poor' 'Arrival_time_convenient:extremely poor']
# ['Catering:poor' 'Catering:need improvement' 'Catering:acceptable'
#  'Catering:good' 'Catering:excellent' 'Catering:extremely poor']
# ['Platform_location:need improvement' 'Platform_location:manageable'
#  'Platform_location:Inconvinient' 'Platform_location:Convinient'
# ...

# %%
shinkansen.boxplot(figsize=(20,3))

# %%
q1 = shinkansen.quantile(0.25)
q3 = shinkansen.quantile(0.75)
IQR = q3-q1
print(IQR)
# Out:
# ID                        47293.0
# Age                          24.0
# Travel_Distance            1178.0
# DepartureDelay_in_Mins       12.0
# ArrivalDelay_in_Mins         13.0
# Overall_Experience            1.0
# dtype: float64

# %%
outliers = (shinkansen<(q1-1.5*IQR))|(shinkansen>(q3+1.5*IQR))
outliers.sum()
# Out:
# Age                           0
# ArrivalDelay_in_Mins       7535
# Arrival_time_convenient       0
# Baggage_handling              0
# Catering                      0
# Checkin_service               0
# Cleanliness                   0
# CustomerType                  0
# DepartureDelay_in_Mins     7814
# Gender                        0
# ID                            0
# Leg_room                      0
# Onboard_entertainment         0
# Onboard_service               0
# Onboardwifi_service           0
# Online_boarding               0
# Online_support                0
# Onlinebooking_Ease            0
# Overall_Experience            0
# Platform_location             0
# Seat_Class                    0
# Seat_comfort                  0
# Travel_Class                  0
# Travel_Distance            1174
# TypeTravel                    0
# dtype: int64

# %%
shinkansen.describe()
# Out:
#                  ID           Age  Travel_Distance  DepartureDelay_in_Mins  \
# count  5.550300e+04  55503.000000     55503.000000            55503.000000
# mean   2.147117e+06     39.403203      1979.200079               14.788029
# std    2.724841e+04     15.084985      1030.538121               37.995164
# min    2.100002e+06      7.000000        50.000000                0.000000
# 25%    2.123486e+06     27.000000      1357.000000                0.000000
# 50%    2.146999e+06     40.000000      1920.000000                0.000000
# 75%    2.170778e+06     51.000000      2535.000000               12.000000
# max    2.194376e+06     85.000000      6950.000000             1017.000000
#
#        ArrivalDelay_in_Mins  Overall_Experience
# count          55503.000000        55503.000000
# mean              15.203827            0.546889
# std               38.427522            0.497801
# min                0.000000            0.000000
# 25%                0.000000            0.000000
# ...

# %%
print(shinkansen['Travel_Distance'].mode())
print(shinkansen['DepartureDelay_in_Mins'].mode())
print(shinkansen['ArrivalDelay_in_Mins'].mode())
# Out:
# 0    1681
# dtype: int64
# 0    0.0
# dtype: float64
# 0    0.0
# dtype: float64

# %%
def treat_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
for feature in shinkansen[['Travel_Distance','DepartureDelay_in_Mins','ArrivalDelay_in_Mins']]: 
    lr,ur=treat_outlier(shinkansen[feature])
    shinkansen[feature]=np.where(shinkansen[feature]>ur,ur,shinkansen[feature])
    shinkansen[feature]=np.where(shinkansen[feature]<lr,lr,shinkansen[feature])

# %%
outliers = (shinkansen<(q1-1.5*IQR))|(shinkansen>(q3+1.5*IQR))
print('The below list shows the number of outliers present in each columns:')
outliers.sum()
# Out:
# The below list shows the number of outliers present in each columns:
# Age                        0
# ArrivalDelay_in_Mins       0
# Arrival_time_convenient    0
# Baggage_handling           0
# Catering                   0
# Checkin_service            0
# Cleanliness                0
# CustomerType               0
# DepartureDelay_in_Mins     0
# Gender                     0
# ID                         0
# Leg_room                   0
# Onboard_entertainment      0
# Onboard_service            0
# Onboardwifi_service        0
# Online_boarding            0
# Online_support             0
# Onlinebooking_Ease         0
# Overall_Experience         0
# Platform_location          0
# Seat_Class                 0
# Seat_comfort               0
# Travel_Class               0
# Travel_Distance            0
# TypeTravel                 0
# dtype: int64

# %%
shinkansen.duplicated().sum()
# Out:
# 0

# %%
for feature in shinkansen.columns: 
    if shinkansen[feature].dtype == 'object': 
        print('\n')
        print('feature:',feature)
        print(pd.Categorical(shinkansen[feature].unique()))
        print(pd.Categorical(shinkansen[feature].unique()).codes)
        shinkansen[feature] = pd.Categorical(shinkansen[feature]).codes
# Out:
# feature: Gender
# [Male, Female]
# Categories (2, object): [Female, Male]
# [1 0]
#
#
# feature: CustomerType
# [Loyal Customer, disloyal Customer]
# Categories (2, object): [Loyal Customer, disloyal Customer]
# [0 1]
#
#
# feature: TypeTravel
# [Personal Travel, Business travel]
# Categories (2, object): [Business travel, Personal Travel]
# [1 0]
#
#
# feature: Travel_Class
# [Eco, Business]
# Categories (2, object): [Business, Eco]
# [1 0]
#
#
# feature: Seat_comfort
# [poor, need improvement, acceptable, good, excellent, extremely poor]
# Categories (6, object): [acceptable, excellent, extremely poor, good, need improvement, poor]
# [5 4 0 3 1 2]
#
#
# feature: Seat_Class
# [Ordinary, Green Car]
# Categories (2, object): [Green Car, Ordinary]
# [1 0]
#
#
# feature: Arrival_time_convenient
# [excellent, need improvement, acceptable, good, poor, extremely poor]
# Categories (6, object): [acceptable, excellent, extremely poor, good, need improvement, poor]
# [1 4 0 3 5 2]
#
#
# ...

# %%
shinkansen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55503 entries, 1 to 94375
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       55503 non-null  int64
#  1   Gender                   55503 non-null  int8
#  2   CustomerType             55503 non-null  int8
#  3   Age                      55503 non-null  float64
#  4   TypeTravel               55503 non-null  int8
#  5   Travel_Class             55503 non-null  int8
#  6   Travel_Distance          55503 non-null  float64
#  7   DepartureDelay_in_Mins   55503 non-null  float64
#  8   ArrivalDelay_in_Mins     55503 non-null  float64
#  9   Overall_Experience       55503 non-null  int64
#  10  Seat_comfort             55503 non-null  int8
#  11  Seat_Class               55503 non-null  int8
#  12  Arrival_time_convenient  55503 non-null  int8
#  13  Catering                 55503 non-null  int8
# ...

# %%
fig,ax = plt.subplots(figsize=(15,10))
sns.heatmap(shinkansen.corr(),annot=True,cmap="magma")
plt.show()

# %%
df = shinkansen.drop(['ID','Overall_Experience'], axis =1)

df.head()
# Out:
#    Gender  CustomerType   Age  TypeTravel  Travel_Class  Travel_Distance  \
# 1       1             0  48.0           1             1           2200.0
# 2       0             0  43.0           0             0           1061.0
# 4       0             0  50.0           0             0           1981.0
# 5       1             0  44.0           0             0           2810.0
# 6       1             0  56.0           1             1           2029.0
#
#    DepartureDelay_in_Mins  ArrivalDelay_in_Mins  Seat_comfort  Seat_Class  \
# 1                     9.0                   0.0             5           1
# 2                    30.0                  32.5             4           0
# 4                     0.0                   0.0             0           1
# 5                     0.0                   0.0             4           1
# 6                     0.0                   0.0             3           0
#
#    ...  Onboardwifi_service  Onboard_entertainment  Online_support  \
# ...

# %%
from scipy.stats import zscore
df=df.apply(zscore)
df.head()
# Out:
#      Gender  CustomerType       Age  TypeTravel  Travel_Class  \
# 1  1.018017     -0.472505  0.569896    1.483096      0.951089
# 2 -0.982302     -0.472505  0.238438   -0.674265     -1.051426
# 4 -0.982302     -0.472505  0.702479   -0.674265     -1.051426
# 5  1.018017     -0.472505  0.304729   -0.674265     -1.051426
# 6  1.018017     -0.472505  1.100230    1.483096      0.951089
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 1         0.234882                0.144393             -0.663443
# 2        -0.910168                2.015006              2.044034
# 4         0.014719               -0.657298             -0.663443
# 5         0.848122               -0.657298             -0.663443
# 6         0.062974               -0.657298             -0.663443
#
#    Seat_comfort  Seat_Class  ...  Onboardwifi_service  Onboard_entertainment  \
# 1      1.348061    1.006816  ...             0.372721               1.673731
# ...

# %%
df.boxplot(figsize=(20,3))

# %%
cov_matrix = np.cov(df.T)
print('Covariance Matrix \n%s', cov_matrix)
# Out:
# Covariance Matrix
# %s [[ 1.00001802e+00 -3.10298803e-02  4.94868689e-03  1.31684774e-02
#   -3.95763077e-03  1.26817423e-01 -7.42245165e-04 -8.60850193e-05
#    1.91908400e-02  5.44708070e-03 -2.07592974e-02  1.25968890e-02
#   -1.73849860e-02  2.72656174e-02  4.58745161e-02  5.43926921e-02
#    3.58671910e-02  7.86978031e-03  9.88363382e-03 -1.81168966e-02
#    1.28294193e-02 -1.02755573e-02  4.39746695e-02]
#  [-3.10298803e-02  1.00001802e+00 -2.81824877e-01 -3.09643053e-01
#    8.04437598e-02  2.54639727e-02  7.92630693e-03  1.21584033e-02
#    5.19180846e-03  1.06386791e-03 -1.53771576e-03  9.18554585e-03
#   -8.57598116e-02  5.20009625e-02  8.36752058e-02  1.03356859e-01
#    6.50994371e-02  6.69174118e-04  1.67826795e-02 -3.91608106e-02
#    2.97319063e-02 -2.38451625e-02  9.09126303e-02]
#  [ 4.94868689e-03 -2.81824877e-01  1.00001802e+00 -4.93252113e-02
#   -1.36649121e-01 -2.53230031e-01 -6.69053277e-03 -8.36439200e-03
# ...

# %%
# Step 2- Get eigen values and eigen vector
eig_vals, eig_vecs = np.linalg.eig(cov_matrix)
print('Eigen Vectors \n%s', eig_vecs)
print('\n Eigen Values \n%s', eig_vals)
# Out:
# Eigen Vectors
# %s [[-3.93404307e-02 -7.95604648e-03 -4.14410379e-02  7.32617364e-03
#   -3.64131335e-02  2.13914076e-02 -5.90742341e-01  3.84854486e-01
#   -1.52941752e-01 -1.08446599e-02 -6.30761741e-01 -7.43363821e-05
#   -4.86102900e-03  1.26366072e-02  8.17692655e-03  6.04849082e-02
#   -2.36087099e-01  4.44112725e-02 -1.07767117e-02 -4.38253211e-03
#    1.17680770e-01 -1.70358641e-02 -2.19870102e-02]
#  [-8.18090343e-02 -8.09205177e-03 -1.05226973e-01  4.90364823e-02
#   -2.72766774e-01  4.96474817e-01  3.95299282e-01 -9.53443045e-02
#    7.23559658e-02 -2.89832440e-02 -4.04127548e-01  3.82559052e-03
#   -7.25305506e-02 -1.31636251e-01  3.62985491e-01  7.50830692e-02
#   -1.33500487e-01  3.38865836e-02  1.03530264e-01 -9.10745604e-02
#   -3.51574952e-01  3.02490483e-02 -4.03227967e-02]
#  [ 5.63609587e-02  2.42735363e-02  1.18742579e-01 -4.67352411e-02
#    5.71303249e-02 -6.42532442e-01  1.47623429e-01  2.51540753e-01
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'CustomerType', 'Age', 'TypeTravel', 'Travel_Class',
#        'Travel_Distance', 'DepartureDelay_in_Mins', 'ArrivalDelay_in_Mins',
#        'Seat_comfort', 'Seat_Class', 'Arrival_time_convenient', 'Catering',
#        'Platform_location', 'Onboardwifi_service', 'Onboard_entertainment',
#        'Online_support', 'Onlinebooking_Ease', 'Onboard_service', 'Leg_room',
#        'Baggage_handling', 'Checkin_service', 'Cleanliness',
#        'Online_boarding'],
#       dtype='object')

# %%
tot = sum(eig_vals)
var_exp = [( i /tot ) * 100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
print("Cumulative Variance Explained", cum_var_exp)
# Out:
# Cumulative Variance Explained [ 13.35479869  23.38884943  32.24930878  40.30043232  47.53035935
#   53.59411821  58.57672303  63.06458261  67.48596226  71.83289105
#   75.75790909  79.16758614  82.30586851  85.23551979  87.78088298
#   90.23361257  92.37820678  94.13587057  95.76602531  97.08782413
#   98.34090146  99.31212578 100.        ]

# %%
plt.plot(var_exp)

# %%
plt.figure(figsize=(10 , 5))
plt.bar(range(1, eig_vals.size + 1), var_exp, alpha = 0.5, align = 'center', label = 'Individual explained variance')
plt.step(range(1, eig_vals.size + 1), cum_var_exp, where='mid', label = 'Cumulative explained variance')
plt.ylabel('Explained Variance Ratio')
plt.xlabel('Principal Components')
plt.legend(loc = 'best')
plt.tight_layout()
plt.show()

# %%
# Using scikit learn PCA here. It does all the above steps and maps data to PCA dimensions in one shot
from sklearn.decomposition import PCA

# NOTE - we are generating only 7 PCA dimensions (dimensionality reduction from 9 to 7)

pca = PCA(n_components=16)
data_reduced = pca.fit_transform(df)
data_reduced.transpose()
# Out:
# array([[ 2.10027759, -0.4566104 , -0.20448248, ...,  1.50303748,
#          4.10442809, -1.24035234],
#        [-0.46142293, -1.74696003,  2.26496339, ...,  0.22419125,
#         -0.21409491, -1.048741  ],
#        [ 0.95896644, -1.05956631,  0.91820679, ..., -1.62036288,
#         -0.42405451, -2.38980628],
#        ...,
#        [ 2.17981887,  0.14634514, -0.04854813, ...,  0.90010007,
#          0.46658529,  0.29409851],
#        [ 0.54341705, -0.05330289, -0.16448943, ...,  0.48832261,
#         -0.37249362, -0.31392096],
#        [ 0.54661631, -0.82683109, -0.13626476, ...,  0.62588632,
#         -1.67273113, -1.36079741]])

# %%
pca.components_
# Out:
# array([[ 3.93404307e-02,  8.18090343e-02, -5.63609587e-02,
#          1.39664074e-02,  8.65352850e-02,  1.38270697e-02,
#          2.10012551e-02,  2.66258199e-02,  2.94994911e-01,
#          2.00677863e-03,  1.41191020e-01,  1.96486983e-01,
#         -7.37255321e-02,  3.82475483e-01,  2.61297257e-01,
#          3.64410800e-01,  4.63614891e-01,  1.77083436e-01,
#          1.37066752e-01,  1.39964937e-01,  9.27002426e-02,
#          1.63528200e-01,  4.01480222e-01],
#        [ 7.95604648e-03,  8.09205177e-03, -2.42735363e-02,
#          5.58536176e-02,  6.91415808e-02, -1.83766332e-02,
#         -2.34038785e-02, -2.19149259e-02, -4.38355574e-01,
#          5.23262022e-03, -4.80207312e-01, -5.39042424e-01,
#          2.08415546e-01,  1.91523611e-01, -2.25278289e-01,
#          1.86332929e-01,  2.26174549e-01,  5.85795729e-02,
#          3.32496675e-02,  6.35096550e-02,  1.90699929e-02,
#          8.10235382e-02,  2.10771792e-01],
# ...

# %%
df_comp = pd.DataFrame(pca.components_,columns=list(df))
df_comp.head()
# Out:
#      Gender  CustomerType       Age  TypeTravel  Travel_Class  \
# 0  0.039340      0.081809 -0.056361    0.013966      0.086535
# 1  0.007956      0.008092 -0.024274    0.055854      0.069142
# 2 -0.041441     -0.105227  0.118743   -0.053848     -0.054281
# 3  0.007326      0.049036 -0.046735   -0.072173     -0.026865
# 4 -0.036413     -0.272767  0.057130    0.668247      0.595387
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0         0.013827                0.021001              0.026626
# 1        -0.018377               -0.023404             -0.021915
# 2        -0.062660               -0.034807             -0.034132
# 3         0.105208                0.695235              0.695462
# 4        -0.300339                0.077090              0.079109
#
#    Seat_comfort  Seat_Class  ...  Onboardwifi_service  Onboard_entertainment  \
# 0      0.294995    0.002007  ...             0.382475               0.261297
# ...

# %%
df_comp.shape
# Out:
# (16, 23)

# %%
df1 = shinkansen[['Gender','CustomerType','Age','TypeTravel','Travel_Class','Travel_Distance','DepartureDelay_in_Mins','ArrivalDelay_in_Mins','Seat_comfort','Seat_Class','Arrival_time_convenient','Online_support','Onlinebooking_Ease','Onboard_service','Checkin_service','Cleanliness']]

# %%
df1.head()
# Out:
#    Gender  CustomerType   Age  TypeTravel  Travel_Class  Travel_Distance  \
# 1       1             0  48.0           1             1           2200.0
# 2       0             0  43.0           0             0           1061.0
# 4       0             0  50.0           0             0           1981.0
# 5       1             0  44.0           0             0           2810.0
# 6       1             0  56.0           1             1           2029.0
#
#    DepartureDelay_in_Mins  ArrivalDelay_in_Mins  Seat_comfort  Seat_Class  \
# 1                     9.0                   0.0             5           1
# 2                    30.0                  32.5             4           0
# 4                     0.0                   0.0             0           1
# 5                     0.0                   0.0             4           1
# 6                     0.0                   0.0             3           0
#
#    Arrival_time_convenient  Online_support  Onlinebooking_Ease  \
# ...

# %%
df1.shape
# Out:
# (55503, 16)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix,plot_confusion_matrix

# %%
X = df1.copy()

# %%
y = shinkansen['Overall_Experience']

# %% [markdown]
# SPLIT DATA

# %%
# Split X and y into training and test set in 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1,stratify=y)

# %%
y_train.value_counts(1)

# %%
y_test.value_counts(1)

# %%
grid={'penalty':['l2','none'],
      'solver':['sag','lbfgs'],
      'tol':[0.0001,0.00001]}

# %%
model = LogisticRegression(max_iter=10000,n_jobs=2)

# %%
grid_search = GridSearchCV(estimator = model, param_grid = grid, cv = 3,n_jobs=-1,scoring='f1')

# %%
grid_search.fit(X_train, y_train)

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)

# %%
best_model = grid_search.best_estimator_

# %%
# Prediction on the training set

ytrain_predict = best_model.predict(X_train)
ytest_predict = best_model.predict(X_test)

# %%
## Getting the probabilities on the test set

ytest_predict_prob=best_model.predict_proba(X_test)
pd.DataFrame(ytest_predict_prob).head()

# %%
## Confusion matrix on the training data

plot_confusion_matrix(best_model,X_train,y_train)
print(classification_report(y_train, ytrain_predict),'\n');

# %%
## Confusion matrix on the test data

plot_confusion_matrix(best_model,X_test,y_test)
print(classification_report(y_test, ytest_predict),'\n');

# %%
travel1 = pd.read_csv("Traveldata_test.csv");
survey1 = pd.read_csv("Surveydata_test.csv");

# %%
shinkansen_test = pd.merge(travel1,survey1,on='ID')
shinkansen_test.head()
# Out:
#         ID  Gender       CustomerType   Age       TypeTravel Travel_Class  \
# 0  3100001  Female                NaN  36.0  Business travel     Business
# 1  3100002  Female  disloyal Customer  21.0  Business travel     Business
# 2  3100003    Male     Loyal Customer  60.0  Business travel     Business
# 3  3100004  Female     Loyal Customer  29.0  Personal Travel          Eco
# 4  3100005    Male  disloyal Customer  18.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              532                     0.0                   0.0
# 1             1425                     9.0                  28.0
# 2             2832                     0.0                   0.0
# 3             1352                     0.0                   0.0
# 4             1610                    17.0                   0.0
#
#      Seat_comfort  ... Onboardwifi_service Onboard_entertainment  \
# ...

# %%
df2 = shinkansen_test[['Gender','CustomerType','Age','TypeTravel','Travel_Class','Travel_Distance','DepartureDelay_in_Mins','ArrivalDelay_in_Mins','Seat_comfort','Seat_Class','Arrival_time_convenient','Online_support','Onlinebooking_Ease','Onboard_service','Checkin_service','Cleanliness']]

# %%
df2.isnull().sum()
# Out:
# Gender                       30
# CustomerType               3383
# Age                          11
# TypeTravel                 3448
# Travel_Class                  0
# Travel_Distance               0
# DepartureDelay_in_Mins       29
# ArrivalDelay_in_Mins        123
# Seat_comfort                 22
# Seat_Class                    0
# Arrival_time_convenient    3325
# Online_support               26
# Onlinebooking_Ease           18
# Onboard_service            2872
# Checkin_service              22
# Cleanliness                   2
# dtype: int64

# %%
df2.describe()
# Out:
#                 Age  Travel_Distance  DepartureDelay_in_Mins  \
# count  35591.000000     35602.000000            35573.000000
# mean      39.446995      1987.151761               14.880696
# std       15.137554      1024.308863               37.895453
# min        7.000000        50.000000                0.000000
# 25%       27.000000      1360.000000                0.000000
# 50%       40.000000      1929.000000                0.000000
# 75%       51.000000      2559.000000               13.000000
# max       85.000000      6868.000000              978.000000
#
#        ArrivalDelay_in_Mins
# count          35479.000000
# mean              15.308802
# std               38.531293
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%               13.000000
# max              970.000000

# %%
df2['Gender'].fillna(str(df2['Gender'].mode()),inplace=True)
df2['CustomerType'].fillna(str(df2['CustomerType'].mode()),inplace=True)
df2['TypeTravel'].fillna(str(df2['TypeTravel'].mode()),inplace=True)
df2['Seat_comfort'].fillna(str(df2['Seat_comfort'].mode()),inplace=True)
df2['Arrival_time_convenient'].fillna(str(df2['Arrival_time_convenient'].mode()),inplace=True)
df2['Online_support'].fillna(str(df2['Online_support'].mode()),inplace=True)
df2['Onlinebooking_Ease'].fillna(str(df2['Onlinebooking_Ease'].mode()),inplace=True)
df2['Onboard_service'].fillna(str(df2['Onboard_service'].mode()),inplace=True)
df2['Checkin_service'].fillna(str(df2['Checkin_service'].mode()),inplace=True)
df2['Cleanliness'].fillna(str(df2['Cleanliness'].mode()),inplace=True)
# Out:
# C:\Users\karthika\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df2.isnull().sum()
# Out:
# Gender                       0
# CustomerType                 0
# Age                         11
# TypeTravel                   0
# Travel_Class                 0
# Travel_Distance              0
# DepartureDelay_in_Mins      29
# ArrivalDelay_in_Mins       123
# Seat_comfort                 0
# Seat_Class                   0
# Arrival_time_convenient      0
# Online_support               0
# Onlinebooking_Ease           0
# Onboard_service              0
# Checkin_service              0
# Cleanliness                  0
# dtype: int64

# %%
df2['Age'].fillna(df2['Age'].mean(),inplace=True)
df2['DepartureDelay_in_Mins'].fillna(df2['DepartureDelay_in_Mins'].mean(),inplace=True)
df2['ArrivalDelay_in_Mins'].fillna(df2['ArrivalDelay_in_Mins'].mean(),inplace=True)

# %%
df2.isnull().sum()
# Out:
# Gender                     0
# CustomerType               0
# Age                        0
# TypeTravel                 0
# Travel_Class               0
# Travel_Distance            0
# DepartureDelay_in_Mins     0
# ArrivalDelay_in_Mins       0
# Seat_comfort               0
# Seat_Class                 0
# Arrival_time_convenient    0
# Online_support             0
# Onlinebooking_Ease         0
# Onboard_service            0
# Checkin_service            0
# Cleanliness                0
# dtype: int64

# %%
df2.describe()
# Out:
#                 Age  Travel_Distance  DepartureDelay_in_Mins  \
# count  35602.000000     35602.000000            35602.000000
# mean      39.446995      1987.151761               14.880696
# std       15.135215      1024.308863               37.880016
# min        7.000000        50.000000                0.000000
# 25%       27.000000      1360.000000                0.000000
# 50%       40.000000      1929.000000                0.000000
# 75%       51.000000      2559.000000               13.000000
# max       85.000000      6868.000000              978.000000
#
#        ArrivalDelay_in_Mins
# count          35602.000000
# mean              15.308802
# std               38.464673
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%               13.000000
# max              970.000000

# %%
for feature in df2.columns: 
    if df2[feature].dtype == 'object': 
        print('\n')
        print('feature:',feature)
        print(pd.Categorical(df2[feature].unique()))
        print(pd.Categorical(df2[feature].unique()).codes)
        df2[feature] = pd.Categorical(df2[feature]).codes
# Out:
# feature: Gender
# [Female, Male, 0    Female\ndtype: object]
# Categories (3, object): [0    Female\ndtype: object, Female, Male]
# [1 2 0]
#
#
# feature: CustomerType
# [0    Loyal Customer\ndtype: object, disloyal Customer, Loyal Customer]
# Categories (3, object): [0    Loyal Customer\ndtype: object, Loyal Customer, disloyal Customer]
# [0 2 1]
#
#
# feature: TypeTravel
# [Business travel, Personal Travel, 0    Business travel\ndtype: object]
# Categories (3, object): [0    Business travel\ndtype: object, Business travel, Personal Travel]
# [1 2 0]
#
#
# feature: Travel_Class
# [Business, Eco]
# Categories (2, object): [Business, Eco]
# [0 1]
#
#
# feature: Seat_comfort
# [acceptable, extremely poor, excellent, poor, need improvement, good, 0    acceptable\ndtype: object]
# Categories (7, object): [0    acceptable\ndtype: object, acceptable, excellent, extremely poor, good, need improvement, poor]
# [1 3 2 6 5 4 0]
#
#
# feature: Seat_Class
# [Green Car, Ordinary]
# ...

# %%
df2.head()
# Out:
#    Gender  CustomerType   Age  TypeTravel  Travel_Class  Travel_Distance  \
# 0       1             0  36.0           1             0              532
# 1       1             2  21.0           1             0             1425
# 2       2             1  60.0           1             0             2832
# 3       1             1  29.0           2             1             1352
# 4       2             2  18.0           1             0             1610
#
#    DepartureDelay_in_Mins  ArrivalDelay_in_Mins  Seat_comfort  Seat_Class  \
# 0                     0.0                   0.0             1           0
# 1                     9.0                  28.0             3           1
# 2                     0.0                   0.0             2           1
# 3                     0.0                   0.0             1           0
# 4                    17.0                   0.0             2           1
#
#    Arrival_time_convenient  Online_support  Onlinebooking_Ease  \
# ...

# %%
from scipy.stats import zscore
df2=df2.apply(zscore)
df2.head()
# Out:
#      Gender  CustomerType       Age  TypeTravel  Travel_Class  \
# 0 -0.978447     -2.118541 -0.227750   -0.307496     -1.038491
# 1 -0.978447      1.841883 -1.218830   -0.307496     -1.038491
# 2  1.015182     -0.138329  1.357978   -0.307496     -1.038491
# 3 -0.978447     -0.138329 -0.690254    1.404921      0.962936
# 4  1.015182      1.841883 -1.417046   -0.307496     -1.038491
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0        -1.420638               -0.392843             -0.398002
# 1        -0.548819               -0.155248              0.329949
# 2         0.824810               -0.392843             -0.398002
# 3        -0.620087               -0.392843             -0.398002
# 4        -0.368206                0.055949             -0.398002
#
#    Seat_comfort  Seat_Class  Arrival_time_convenient  Online_support  \
# 0     -1.410361   -1.003320                -1.110926        0.217433
# ...

# %%
trainset_x = df1.copy()
trainset_y = shinkansen['Overall_Experience']

# %%
trainset_x= trainset_x.apply(zscore)

# %%
testset_x = df2.copy()

# %%
testset_x= testset_x.apply(zscore)

# %%
grid_search.fit(trainset_x, trainset_y)

# %%
print(grid_search.best_params_,'\n')
print(grid_search.best_estimator_)

# %%
best_model1 = grid_search.best_estimator_

# %%
# Prediction on the training set

df2['Overall_Experience'] = best_model1.predict(testset_x)

# %%
df2['ID'] = shinkansen_test['ID']

# %%
df2.head()

# %%
df2.rename(columns={'Overall_Experience_Test':'Overall_Experience'},inplace=True)

# %%
df2.head()

# %%
output = df2[['ID','Overall_Experience']]

# %%
output.to_csv("Model1_update.csv",index=False)

# %% [markdown]
# # LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import metrics,model_selection
from sklearn.preprocessing import scale

# %%
clf = LinearDiscriminantAnalysis()
model2=clf.fit(trainset_x,trainset_y)

# %%
# Training Data Class Prediction with a cut-off value of 0.5
pred_class_train = model2.predict(trainset_x)

# Test Data Class Prediction with a cut-off value of 0.5
pred_class_test = model2.predict(testset_x)

# %%
pred_prob_train = model2.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = model2.predict_proba(X_test)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(trainset_y,pred_class_train)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,pred_class_test)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,pred_class_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,pred_class_test),'\n')

# %%
model2=clf.fit(trainset_x, trainset_y)

# %%
# Training Data Class Prediction with a cut-off value of 0.5
pred_class_train = model2.predict(trainset_x)

# Test Data Class Prediction with a cut-off value of 0.5
df2['Overall_Experience'] = model2.predict(testset_x)

# %%
output1 = df2[['ID','Overall_Experience']]

# %%
output1.to_csv("Model2_Update.csv",index=False)

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier

# %%
param_grid = {
    'hidden_layer_sizes': [(100,100,100,100)],
    'activation': ['logistic', 'relu'],
    'solver': ['sgd', 'adam'],
    'tol': [0.001,0.0001],
    'max_iter' : [5000]
}

rfcl = MLPClassifier()

grid_search = GridSearchCV(estimator = rfcl, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(trainset_x, trainset_y)

# %%
grid_search.best_params_

# %%
best_grid = grid_search.best_estimator_

# %%
df2['Overall_Experience'] = best_grid.predict(testset_x)

# %%
output1 = df2[['ID','Overall_Experience']]
output1.to_csv("Model7_Update2.csv",index=False)

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

# %%
dt_model = DecisionTreeClassifier(criterion = 'gini' )

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [10, 15, 20],
    'min_samples_leaf': [20],
    'min_samples_split': [10, 20, 30]
}

dt_model = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dt_model, param_grid = param_grid, cv = 3)

# %%
grid_search.fit(trainset_x, trainset_y)

# %%
grid_search.best_params_

# %%
best_grid = grid_search.best_estimator_

# %%
df2['Overall_Experience'] = best_grid.predict(testset_x)

# %%
output1 = df2[['ID','Overall_Experience']]
output1.to_csv("Model6_Update2.csv",index=False)
